# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df[df["Class"] == 1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
sns.countplot(x="Class",data=df)
plt.show()

# %%
#Undersampling Example
shuffled_df = df.sample(frac=1,random_state=4)
shuffled_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 135406   81240.0  0.999672 -0.034679  0.446984  1.374760 -0.272838  0.033625
# 137826   82347.0 -0.844413  1.032424  1.090921 -0.671593 -0.006061 -0.621923
# 70830    54035.0 -0.474271  1.027526  1.546229 -0.082036  0.180465 -0.407305
# 194993  130854.0 -1.619583 -0.460686  0.219034 -0.418723  0.933105 -0.477342
# 87575    61745.0 -1.159349  0.816687  1.743063 -0.724069 -0.398590 -0.796834
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 135406  0.025702  0.118362  0.052625  ... -0.006060  0.042805 -0.095535
# 137826  0.322604  0.513167 -0.705964  ... -0.080023 -0.535090  0.005324
# 70830   0.695010  0.025371 -0.522539  ... -0.186400 -0.415345  0.014862
# 194993  0.902804 -0.120123  0.138692  ... -0.009905  0.886662  0.620723
# 87575   0.275232  0.405158 -0.238336  ... -0.215970 -0.746148 -0.141145
#
# ...

# %%
fraud_df = shuffled_df.loc[shuffled_df["Class"] == 1]
fraud_df.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
non_fraud_df = shuffled_df.loc[shuffled_df["Class"]==0].sample(n=492,random_state=42)
non_fraud_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 157731  110347.0 -0.336669  0.840320 -0.693547 -0.739751  1.910327  1.241690
# 78999    57810.0 -1.391472  0.882756  1.605490 -1.585724  0.510154 -0.626091
# 142859   84977.0 -0.970188  1.334735  0.665948 -0.114765 -0.229420 -0.585999
# 153258   98342.0  2.010061 -0.056283 -0.883406  0.536444 -0.135828 -0.914798
# 209864  137746.0  0.524951  0.707794 -0.095986  0.988461  0.064195 -0.797652
# ...          ...       ...       ...       ...       ...       ...       ...
# 30792    36082.0 -1.280608  1.602133  0.705905  1.093425 -0.237750  0.945421
# 254619  156824.0 -0.479100 -0.077534  0.404028 -0.666043  1.264096 -0.829802
# 154095  100876.0  1.908030 -0.457748  0.333732  0.470267 -0.960866 -0.099910
# 136926   81937.0  1.281151  0.132456  0.212079  0.133399 -0.476419 -1.306907
# 172969  121309.0 -1.452337 -0.466853 -0.555007 -3.355574  2.117199  3.431942
#
# ...

# %%
normalized_df = pd.concat([fraud_df,non_fraud_df])

# %%
plt.figure(figsize=(8, 8))
sns.countplot('Class', data=normalized_df)
plt.title('Balanced Classes')
plt.show()

# %%
#Oversampling Example - SMOTE
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(sampling_strategy="minority",random_state=7)

oversampled_trainX, oversampled_trainY = sm.fit_sample(df.drop('Class', axis=1), df['Class'])
oversampled_train = pd.concat([pd.DataFrame(oversampled_trainX), pd.DataFrame(oversampled_trainY)], axis=1)
oversampled_train.columns = normalized_df.columns
oversampled_train.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
oversampled_train["Class"].value_counts()
# Out:
# 1    284315
# 0    284315
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="Class", data = oversampled_train)
plt.show()

# %%
oversampled_train.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
oversampled_train.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  568630.000000  568630.000000  568630.000000  568630.000000
# mean    87861.913493      -2.476877       1.910150      -3.644683
# std     48161.914552       5.450422       3.633499       6.153232
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     46048.000000      -3.061417      -0.098598      -5.224231
# 50%     80385.000000      -0.819213       1.015966      -1.550175
# 75%    134768.998403       0.821546       2.885333       0.268185
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  568630.000000  568630.000000  568630.000000  568630.000000
# mean        2.326261      -1.624067      -0.718674      -2.924462
# std         3.142734       4.134399       1.706687       5.699271
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.tree import DecisionTreeClassifier

#Create an object of the classifier.
bbc = BalancedBaggingClassifier(base_estimator=DecisionTreeClassifier(),
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0)

y_train = df['Class']
X_train = df.drop(['Class'], axis=1, inplace=False)

#Train the classifier.
bbc.fit(X_train, y_train)
preds = bbc.predict(X_train)
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a = np.array([0,1,2,5,4,1])
a
# Out:
# array([0, 1, 2, 5, 4, 1])

# %%
b = a[np.where(a == max(a))]

# %%
# Out:
# array([25])

# %%
res = np.where(a==4)

# %%
res
# Out:
# (array([4], dtype=int64),)
